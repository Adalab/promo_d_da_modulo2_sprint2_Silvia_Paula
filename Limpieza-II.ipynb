# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/Usuario/Desktop'

# %%
os.chdir("pairs_modulo_2/promo_d_da_modulo2_sprint2_Silvia_Paula/")

# %%
df_bank = pd.read_csv("datos/bank-additional-full-edit1.csv", index_col= 0)
df_bank
# Out:
#        age          job  marital            education  default  housing  loan  \
# 0       56    housemaid  married             basic.4y      0.0      0.0   0.0
# 1       57     services  married          high.school      NaN      0.0   0.0
# 2       37     services  married          high.school      0.0      1.0   0.0
# 3       40       admin.  married             basic.6y      0.0      0.0   0.0
# 4       56     services  married          high.school      0.0      0.0   1.0
# ...    ...          ...      ...                  ...      ...      ...   ...
# 41183   73      retired  married  professional.course      0.0      1.0   0.0
# 41184   46  blue-collar  married  professional.course      0.0      0.0   0.0
# 41185   56      retired  married    university.degree      0.0      1.0   0.0
# 41186   44   technician  married  professional.course      0.0      0.0   0.0
# 41187   74      retired  married  professional.course      0.0      1.0   0.0
#
#          contact  duration  campaign  pdays  previous     poutcome  \
# 0      telephone       261         1    999         0  NONEXISTENT
# 1      telephone       149         1    999         0  NONEXISTENT
# 2      telephone       226         1    999         0  NONEXISTENT
# 3      telephone       151         1    999         0  NONEXISTENT
# 4      telephone       307         1    999         0  NONEXISTENT
# ...          ...       ...       ...    ...       ...          ...
# 41183   cellular       334         1    999         0  NONEXISTENT
# 41184   cellular       383         1    999         0  NONEXISTENT
# 41185   cellular       189         2    999         0  NONEXISTENT
# 41186   cellular       442         1    999         0  NONEXISTENT
# 41187   cellular       239         3    999         1      FAILURE
#
#        emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  \
# 0               1.1          93.994          -36.4      4.857       5191.0
# 1               1.1          93.994          -36.4      4.857       5191.0
# 2               1.1          93.994          -36.4      4.857       5191.0
# 3               1.1          93.994          -36.4      4.857       5191.0
# 4               1.1          93.994          -36.4      4.857       5191.0
# ...             ...             ...            ...        ...          ...
# 41183          -1.1          94.767          -50.8      1.028       4963.6
# 41184          -1.1          94.767          -50.8      1.028       4963.6
# 41185          -1.1          94.767          -50.8      1.028       4963.6
# 41186          -1.1          94.767          -50.8      1.028       4963.6
# 41187          -1.1          94.767          -50.8      1.028       4963.6
#
#          y  month_day_week
# 0       no  ['may', 'mon']
# 1       no  ['may', 'mon']
# 2       no  ['may', 'mon']
# 3       no  ['may', 'mon']
# 4       no  ['may', 'mon']
# ...    ...             ...
# 41183  yes  ['nov', 'fri']
# 41184   no  ['nov', 'fri']
# 41185   no  ['nov', 'fri']
# 41186  yes  ['nov', 'fri']
# 41187   no  ['nov', 'fri']
#
# [41176 rows x 20 columns]

# %% [markdown]
# Columnas loan, housing y default: estas columnas contienen valores únicos de 0 y 1. Esto puede parecer poco intuitivo a la hora de la extracción de conclusiones y en las visualizaciones.
#
# El objetivo de este ejercicio es que cambies los valores númericos por "Si" y "No". A que corresponde cada uno de los valores lo tenéis en el pair de Limpieza I.

# %%
mapa = {0: "No",
       1: "Si"}

# %%
df_bank["loan2"] = df_bank["loan"].map(mapa, na_action="ignore")

# %%
df_bank["housing2"] = df_bank["housing"].map(mapa, na_action="ignore")

# %%
df_bank["default2"] = df_bank["default"].map(mapa, na_action="ignore")

# %%
df_bank[df_bank["default"] == 1.0]
# Out:
#        age         job  marital            education  default  housing  loan  \
# 21580   48  technician  married  professional.course      1.0      0.0   0.0
# 21581   48  technician  married  professional.course      1.0      1.0   0.0
# 24866   31  unemployed  married          high.school      1.0      0.0   0.0
#
#         contact  duration  campaign  ...  emp_var_rate  cons_price_idx  \
# 21580  cellular        66         1  ...           1.4          93.444
# 21581  cellular       133         1  ...           1.4          93.444
# 24866  cellular       111         2  ...          -0.1          93.200
#
#       cons_conf_idx  euribor3m  nr_employed   y  month_day_week  loan2  \
# 21580         -36.1      4.963       5228.1  no  ['aug', 'tue']     No
# 21581         -36.1      4.963       5228.1  no  ['aug', 'tue']     No
# 24866         -42.0      4.153       5195.8  no  ['nov', 'tue']     No
#
#       housing2 default2
# 21580       No       Si
# 21581       Si       Si
# 24866       No       Si
#
# [3 rows x 23 columns]

# %%
df_bank.sample(5)
# Out:
#        age          job  marital          education  default  housing  loan  \
# 37218   29       admin.   single  university.degree      0.0      0.0   0.0
# 16507   22  blue-collar   single        high.school      0.0      1.0   0.0
# 37410   66      retired  married                NaN      0.0      0.0   0.0
# 25219   41   technician  married           basic.9y      0.0      1.0   0.0
# 12656   31   technician  married        high.school      0.0      0.0   0.0
#
#          contact  duration  campaign  ...  emp_var_rate  cons_price_idx  \
# 37218   cellular       289         2  ...          -2.9          92.201
# 16507   cellular       123         2  ...           1.4          93.918
# 37410   cellular       147         2  ...          -2.9          92.201
# 25219  telephone       102         2  ...          -0.1          93.200
# 12656   cellular        75         3  ...           1.4          93.918
#
#       cons_conf_idx  euribor3m  nr_employed    y  month_day_week  loan2  \
# 37218         -31.4      0.881       5076.2  yes  ['aug', 'fri']     No
# 16507         -42.7      4.963       5228.1   no  ['jul', 'wed']     No
# 37410         -31.4      0.879       5076.2  yes  ['aug', 'wed']     No
# 25219         -42.0      4.153       5195.8   no  ['nov', 'tue']     No
# 12656         -42.7      4.960       5228.1   no  ['jul', 'mon']     No
#
#       housing2 default2
# 37218       No       No
# 16507       Si       No
# 37410       No       No
# 25219       Si       No
# 12656       No       No
#
# [5 rows x 23 columns]

# %% [markdown]
# Para la columna de education, si nos fijamos en sus valores únicos veremos que tenemos puntos.
#
# El objetivo de este ejercicio es que quitéis los puntos de esos valores y los reemplacéis por espacios.

# %%
df_bank["education2"] = df_bank.apply(lambda df_bank: df_bank["education"].replace(".", " ") if type(df_bank["education"]) == str else df_bank["education"], axis = 1)

# %%
df_bank.head()
# Out:
#    age        job  marital    education  default  housing  loan    contact  \
# 0   56  housemaid  married     basic.4y      0.0      0.0   0.0  telephone
# 1   57   services  married  high.school      NaN      0.0   0.0  telephone
# 2   37   services  married  high.school      0.0      1.0   0.0  telephone
# 3   40     admin.  married     basic.6y      0.0      0.0   0.0  telephone
# 4   56   services  married  high.school      0.0      0.0   1.0  telephone
#
#    duration  campaign  ...  cons_price_idx  cons_conf_idx euribor3m  \
# 0       261         1  ...          93.994          -36.4     4.857
# 1       149         1  ...          93.994          -36.4     4.857
# 2       226         1  ...          93.994          -36.4     4.857
# 3       151         1  ...          93.994          -36.4     4.857
# 4       307         1  ...          93.994          -36.4     4.857
#
#    nr_employed   y  month_day_week  loan2  housing2 default2   education2
# 0       5191.0  no  ['may', 'mon']     No        No       No     basic 4y
# 1       5191.0  no  ['may', 'mon']     No        No      NaN  high school
# 2       5191.0  no  ['may', 'mon']     No        Si       No  high school
# 3       5191.0  no  ['may', 'mon']     No        No       No     basic 6y
# 4       5191.0  no  ['may', 'mon']     Si        No       No  high school
#
# [5 rows x 24 columns]

# %% [markdown]
# Para la columna job, hay un valor único que esta abreviado (admin.), cambiad la abreviatura por el nombre completo.

# %%
df_bank["job2"] = df_bank.apply(lambda df_bank: df_bank["job"].replace("admin.", "administrativo") if type(df_bank["job"]) == str else df_bank["job"], axis = 1)

# %%
df_bank.head()
# Out:
#    age        job  marital    education  default  housing  loan    contact  \
# 0   56  housemaid  married     basic.4y      0.0      0.0   0.0  telephone
# 1   57   services  married  high.school      NaN      0.0   0.0  telephone
# 2   37   services  married  high.school      0.0      1.0   0.0  telephone
# 3   40     admin.  married     basic.6y      0.0      0.0   0.0  telephone
# 4   56   services  married  high.school      0.0      0.0   1.0  telephone
#
#    duration  campaign  ...  cons_conf_idx  euribor3m nr_employed   y  \
# 0       261         1  ...          -36.4      4.857      5191.0  no
# 1       149         1  ...          -36.4      4.857      5191.0  no
# 2       226         1  ...          -36.4      4.857      5191.0  no
# 3       151         1  ...          -36.4      4.857      5191.0  no
# 4       307         1  ...          -36.4      4.857      5191.0  no
#
#    month_day_week  loan2  housing2  default2   education2            job2
# 0  ['may', 'mon']     No        No        No     basic 4y       housemaid
# 1  ['may', 'mon']     No        No       NaN  high school        services
# 2  ['may', 'mon']     No        Si        No  high school        services
# 3  ['may', 'mon']     No        No        No     basic 6y  administrativo
# 4  ['may', 'mon']     Si        No        No  high school        services
#
# [5 rows x 25 columns]

# %% [markdown]
# La columna month_day_week tiene una lista que contiene información muy diferente.
#
# El objetivo de este ejercicio es separar esta columna en dos nuevas, donde tengamos los meses en una columna y los días de la semana en otra.

# %%
df_bank[['month','day_week']] = df_bank['month_day_week'].str.split(',', expand=True, n=1)

# %%
df_bank.head()
# Out:
#    age        job  marital    education  default  housing  loan    contact  \
# 0   56  housemaid  married     basic.4y      0.0      0.0   0.0  telephone
# 1   57   services  married  high.school      NaN      0.0   0.0  telephone
# 2   37   services  married  high.school      0.0      1.0   0.0  telephone
# 3   40     admin.  married     basic.6y      0.0      0.0   0.0  telephone
# 4   56   services  married  high.school      0.0      0.0   1.0  telephone
#
#    duration  campaign  ...  nr_employed   y  month_day_week  loan2  housing2  \
# 0       261         1  ...       5191.0  no  ['may', 'mon']     No        No
# 1       149         1  ...       5191.0  no  ['may', 'mon']     No        No
# 2       226         1  ...       5191.0  no  ['may', 'mon']     No        Si
# 3       151         1  ...       5191.0  no  ['may', 'mon']     No        No
# 4       307         1  ...       5191.0  no  ['may', 'mon']     Si        No
#
#    default2   education2            job2   month day_week
# 0        No     basic 4y       housemaid  ['may'   'mon']
# 1       NaN  high school        services  ['may'   'mon']
# 2        No  high school        services  ['may'   'mon']
# 3        No     basic 6y  administrativo  ['may'   'mon']
# 4        No  high school        services  ['may'   'mon']
#
# [5 rows x 27 columns]

# %%
df_bank.loc[0, "month_day_week"]
# Out:
# "['may', 'mon']"

# %%
re.findall("\w{3}",df_bank.loc[0, "month_day_week"])
# Out:
# ['may', 'mon']

# %% [markdown]
# Guarda el csv con las columnas limpias para seguir trabajando con este dataframe limpio.

# %%
df_bank.to_csv("datos/bank-additional-full-edit2.csv")
